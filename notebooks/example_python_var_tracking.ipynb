# %%
import sys
sys.path.append('..') # Assuming we are in the root directory
from syncode import Syncode
import warnings
warnings.filterwarnings('ignore')

# redirect logging output to logfile
import logging
logging.basicConfig(
    filename='syncode.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)


model_name = "microsoft/phi-2"

# Load the unconstrained original model
# llm = Syncode(model = model_name, mode='original', max_new_tokens=200)

# Load the Syncode augmented model
syn_llm = Syncode(
    model = model_name, 
    mode='grammar_mask', 
    grammar='python_var_tracking', 
    parser='lr',
    parse_output_only=False,
    indent=True,
    opp=False,
    max_new_tokens=30
    )
# Out:
# /home/silas/Documents/coding/python/syncode/notebooks/../syncode/parsers/grammars/python_var_tracking.lark
# [2025-08-09 18:13:14,064-root] - Loading model microsoft/phi-2 with device:cuda, device_map:auto, torch_dtype:torch.bfloat16
# [2025-08-09 18:13:14,067-urllib3.connectionpool] - Starting new HTTPS connection (1): huggingface.co:443
# [2025-08-09 18:13:14,232-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /microsoft/phi-2/resolve/main/config.json HTTP/1.1" 307 0
# [2025-08-09 18:13:14,246-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /api/resolve-cache/models/microsoft/phi-2/ef382358ec9e382308935a992d908de099b64c23/config.json HTTP/1.1" 200 0
# [2025-08-09 18:13:15,359-accelerate.utils.modeling] - We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# [2025-08-09 18:13:18,452-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /microsoft/phi-2/resolve/main/generation_config.json HTTP/1.1" 307 0
# [2025-08-09 18:13:18,466-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /api/resolve-cache/models/microsoft/phi-2/ef382358ec9e382308935a992d908de099b64c23/generation_config.json HTTP/1.1" 200 0
# [2025-08-09 18:13:18,587-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /microsoft/phi-2/resolve/main/custom_generate/generate.py HTTP/1.1" 404 0
# [2025-08-09 18:13:18,795-accelerate.big_modeling] - Some parameters are on the meta device because they were offloaded to the cpu.
# [2025-08-09 18:13:18,917-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /microsoft/phi-2/resolve/main/tokenizer_config.json HTTP/1.1" 307 0
# [2025-08-09 18:13:18,930-urllib3.connectionpool] - https://huggingface.co:443 "HEAD /api/resolve-cache/models/microsoft/phi-2/ef382358ec9e382308935a992d908de099b64c23/tokenizer_config.json HTTP/1.1" 200 0
# [2025-08-09 18:13:19,065-urllib3.connectionpool] - https://huggingface.co:443 "GET /api/models/microsoft/phi-2/tree/main/additional_chat_templates?recursive=False&expand=False HTTP/1.1" 404 64

# %% [markdown]
# # Syncode vs Standard LLM generation of Python program
# We show that in following program the standard LLM generates a python program that has indentation error, while the Syncode LLM generates a correct python program.

# %%
partial_code = "# calculate fibonacci with numpy\nimport"


# partial_code = "a=1\nb=a\n"



# partial_code = "import syncode.larkm as lark\nfrom. import util\n"

output = partial_code+syn_llm.infer(partial_code)[0]
# output = syn_llm.user_input
# output =syn_llm.infer(partial_code)[0]

print(output)
# exec(output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [2025-08-09 18:14:24,345-syncode.parsers.python_var_tracking_parser] - vars: []
# [2025-08-09 18:14:24,744-syncode.parsers.python_var_tracking_parser] - vars: []
# [2025-08-09 18:14:25,136-syncode.parsers.python_var_tracking_parser] - vars: []
# [2025-08-09 18:14:25,538-syncode.parsers.python_var_tracking_parser] - vars: []
# [2025-08-09 18:14:25,938-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:26,335-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:26,734-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:26,737-syncode.grammar_mask.grammar_constrainer] - No acceptable tokens for the current partial code!
# [2025-08-09 18:14:26,739-syncode.grammar_mask.grammar_constrainer] - remainder : b'\n\n', remainder_state: RemainderState.MAYBE_COMPLETE, accept_sequences: {accept_terminals: ['_NL', 'COMMENT', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', 'ASSERT'], accept_terminals: ['_NL', 'WS_INLINE', 'WHILE'], accept_terminals: ['_NL', 'COMMENT', 'DEL'], accept_terminals: ['_NL', 'WS_INLINE', 'YIELD'], accept_terminals: ['_NL', 'COMMENT', 'YIELD'], accept_terminals: ['_NL', '__IGNORE_1', 'BREAK'], accept_terminals: ['_NL', '__IGNORE_1', 'FROM'], accept_terminals: ['_NL', '__IGNORE_1', 'STAR'], accept_terminals: ['_NL', 'TILDE'], accept_terminals: ['_NL', '__IGNORE_1', 'IF'], accept_terminals: ['_NL', 'FROM'], accept_terminals: ['_NL', '_NL'], accept_terminals: ['_NL', 'WS_INLINE', 'LSQB'], accept_terminals: ['_NL', 'STRING'], accept_terminals: ['_NL', 'COMMENT', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'HEX_NUMBER'], accept_terminals: ['_NL', 'WS_INLINE', 'WITH'], accept_terminals: ['_NL', 'WS_INLINE', 'DEC_NUMBER'], accept_terminals: ['_NL', 'NOT'], accept_terminals: ['_NL', '__IGNORE_1', 'LAMBDA'], accept_terminals: ['_NL', '__IGNORE_1', 'PASS'], accept_terminals: ['_NL', 'COMMENT', 'IF'], accept_terminals: ['_NL', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', '_NL'], accept_terminals: ['_NL', 'COMMENT', 'RETURN'], accept_terminals: ['_NL', 'WS_INLINE', 'LONG_STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'EOF'], accept_terminals: ['_NL', '__IGNORE_1', 'WHILE'], accept_terminals: ['_NL', '__IGNORE_1', 'NOT'], accept_terminals: ['_NL', 'COMMENT', 'LONG_STRING'], accept_terminals: ['_NL', 'PASS'], accept_terminals: ['_NL', 'WS_INLINE', 'MINUS'], accept_terminals: ['_NL', '__IGNORE_1', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'TRY'], accept_terminals: ['_NL', 'IMPORT'], accept_terminals: ['_NL', 'WS_INLINE', '$END'], accept_terminals: ['_NL', 'WS_INLINE', 'BREAK'], accept_terminals: ['_NL', 'WS_INLINE', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'RETURN'], accept_terminals: ['WS_INLINE'], accept_terminals: ['_NL', 'DEL'], accept_terminals: ['_NL', '__IGNORE_1', 'LBRACE'], accept_terminals: ['_NL', 'WS_INLINE', 'TRY'], accept_terminals: ['_NL', 'COMMENT', 'FROM'], accept_terminals: ['_NL', 'WS_INLINE', 'TILDE'], accept_terminals: ['_NL', 'HEX_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'MINUS'], accept_terminals: ['_NL', 'COMMENT', 'WITH'], accept_terminals: ['SEMICOLON'], accept_terminals: ['_NL', 'COMMENT', 'LBRACE'], accept_terminals: ['_NL', 'NAME'], accept_terminals: ['_NL', 'COMMENT', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'CLASS'], accept_terminals: ['_NL', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'FOR'], accept_terminals: ['_NL', '__IGNORE_1', 'ASYNC'], accept_terminals: ['_NL', '__IGNORE_1', 'FLOAT_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'NONE'], accept_terminals: ['_NL', 'WS_INLINE', 'LBRACE'], accept_terminals: ['_NL', 'NONLOCAL'], accept_terminals: ['_NL', 'COMMENT', 'LSQB'], accept_terminals: ['_NL', '$END'], accept_terminals: ['_NL', '__IGNORE_1', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'TRUE'], accept_terminals: ['_NL', 'COMMENT', 'LAMBDA'], accept_terminals: ['_NL', 'WS_INLINE', 'STAR'], accept_terminals: ['_NL', 'WS_INLINE', 'PASS'], accept_terminals: ['_NL', '__IGNORE_1', 'NONE'], accept_terminals: ['_NL', '__IGNORE_1', 'IMPORT'], accept_terminals: ['_NL', 'COMMENT', 'DEF'], accept_terminals: ['_NL', 'COMMENT', 'ASYNC'], accept_terminals: ['_NL', 'COMMENT', 'FALSE'], accept_terminals: ['_NL', 'TRUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'PASS'], accept_terminals: ['COMMA'], accept_terminals: ['_NL', 'WS_INLINE', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'NONLOCAL'], accept_terminals: ['_NL', 'WS_INLINE', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'WITH'], accept_termina ...
# [2025-08-09 18:14:27,127-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:27,513-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:27,908-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:28,292-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:28,719-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:29,133-syncode.parsers.python_var_tracking_parser] - vars: [('numpy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:29,136-syncode.grammar_mask.grammar_constrainer] - No acceptable tokens for the current partial code!
# [2025-08-09 18:14:29,138-syncode.grammar_mask.grammar_constrainer] - remainder : b'\n\n# scipy fun\n', remainder_state: RemainderState.MAYBE_COMPLETE, accept_sequences: {accept_terminals: ['_NL', 'COMMENT', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', 'ASSERT'], accept_terminals: ['_NL', 'WS_INLINE', 'WHILE'], accept_terminals: ['_NL', 'COMMENT', 'DEL'], accept_terminals: ['_NL', 'WS_INLINE', 'YIELD'], accept_terminals: ['_NL', 'COMMENT', 'YIELD'], accept_terminals: ['_NL', '__IGNORE_1', 'BREAK'], accept_terminals: ['_NL', '__IGNORE_1', 'FROM'], accept_terminals: ['_NL', '__IGNORE_1', 'STAR'], accept_terminals: ['_NL', 'TILDE'], accept_terminals: ['_NL', '__IGNORE_1', 'IF'], accept_terminals: ['_NL', 'FROM'], accept_terminals: ['_NL', '_NL'], accept_terminals: ['_NL', 'WS_INLINE', 'LSQB'], accept_terminals: ['_NL', 'STRING'], accept_terminals: ['_NL', 'COMMENT', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'HEX_NUMBER'], accept_terminals: ['_NL', 'WS_INLINE', 'WITH'], accept_terminals: ['_NL', 'WS_INLINE', 'DEC_NUMBER'], accept_terminals: ['_NL', 'NOT'], accept_terminals: ['_NL', '__IGNORE_1', 'LAMBDA'], accept_terminals: ['_NL', '__IGNORE_1', 'PASS'], accept_terminals: ['_NL', 'COMMENT', 'IF'], accept_terminals: ['_NL', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', '_NL'], accept_terminals: ['_NL', 'COMMENT', 'RETURN'], accept_terminals: ['_NL', 'WS_INLINE', 'LONG_STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'EOF'], accept_terminals: ['_NL', '__IGNORE_1', 'WHILE'], accept_terminals: ['_NL', '__IGNORE_1', 'NOT'], accept_terminals: ['_NL', 'COMMENT', 'LONG_STRING'], accept_terminals: ['_NL', 'PASS'], accept_terminals: ['_NL', 'WS_INLINE', 'MINUS'], accept_terminals: ['_NL', '__IGNORE_1', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'TRY'], accept_terminals: ['_NL', 'IMPORT'], accept_terminals: ['_NL', 'WS_INLINE', '$END'], accept_terminals: ['_NL', 'WS_INLINE', 'BREAK'], accept_terminals: ['_NL', 'WS_INLINE', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'RETURN'], accept_terminals: ['WS_INLINE'], accept_terminals: ['_NL', 'DEL'], accept_terminals: ['_NL', '__IGNORE_1', 'LBRACE'], accept_terminals: ['_NL', 'WS_INLINE', 'TRY'], accept_terminals: ['_NL', 'COMMENT', 'FROM'], accept_terminals: ['_NL', 'WS_INLINE', 'TILDE'], accept_terminals: ['_NL', 'HEX_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'MINUS'], accept_terminals: ['_NL', 'COMMENT', 'WITH'], accept_terminals: ['SEMICOLON'], accept_terminals: ['_NL', 'COMMENT', 'LBRACE'], accept_terminals: ['_NL', 'NAME'], accept_terminals: ['_NL', 'COMMENT', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'CLASS'], accept_terminals: ['_NL', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'FOR'], accept_terminals: ['_NL', '__IGNORE_1', 'ASYNC'], accept_terminals: ['_NL', '__IGNORE_1', 'FLOAT_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'NONE'], accept_terminals: ['_NL', 'WS_INLINE', 'LBRACE'], accept_terminals: ['_NL', 'NONLOCAL'], accept_terminals: ['_NL', 'COMMENT', 'LSQB'], accept_terminals: ['_NL', '$END'], accept_terminals: ['_NL', '__IGNORE_1', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'TRUE'], accept_terminals: ['_NL', 'COMMENT', 'LAMBDA'], accept_terminals: ['_NL', 'WS_INLINE', 'STAR'], accept_terminals: ['_NL', 'WS_INLINE', 'PASS'], accept_terminals: ['_NL', '__IGNORE_1', 'NONE'], accept_terminals: ['_NL', '__IGNORE_1', 'IMPORT'], accept_terminals: ['_NL', 'COMMENT', 'DEF'], accept_terminals: ['_NL', 'COMMENT', 'ASYNC'], accept_terminals: ['_NL', 'COMMENT', 'FALSE'], accept_terminals: ['_NL', 'TRUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'PASS'], accept_terminals: ['COMMA'], accept_terminals: ['_NL', 'WS_INLINE', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'NONLOCAL'], accept_terminals: ['_NL', 'WS_INLINE', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'WITH'], a ...
# [2025-08-09 18:14:29,566-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:29,955-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:30,341-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:30,750-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:31,173-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:31,567-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:31,950-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>)]
# [2025-08-09 18:14:32,374-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:32,790-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:33,198-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:33,201-syncode.grammar_mask.grammar_constrainer] - No acceptable tokens for the current partial code!
# [2025-08-09 18:14:33,203-syncode.grammar_mask.grammar_constrainer] - remainder : b'\n\n', remainder_state: RemainderState.MAYBE_COMPLETE, accept_sequences: {accept_terminals: ['_NL', 'COMMENT', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', 'ASSERT'], accept_terminals: ['_NL', 'WS_INLINE', 'WHILE'], accept_terminals: ['_NL', 'COMMENT', 'DEL'], accept_terminals: ['_NL', 'WS_INLINE', 'YIELD'], accept_terminals: ['_NL', 'COMMENT', 'YIELD'], accept_terminals: ['_NL', '__IGNORE_1', 'BREAK'], accept_terminals: ['_NL', '__IGNORE_1', 'FROM'], accept_terminals: ['_NL', '__IGNORE_1', 'STAR'], accept_terminals: ['_NL', 'TILDE'], accept_terminals: ['_NL', '__IGNORE_1', 'IF'], accept_terminals: ['_NL', 'FROM'], accept_terminals: ['_NL', '_NL'], accept_terminals: ['_NL', 'WS_INLINE', 'LSQB'], accept_terminals: ['_NL', 'STRING'], accept_terminals: ['_NL', 'COMMENT', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'HEX_NUMBER'], accept_terminals: ['_NL', 'WS_INLINE', 'WITH'], accept_terminals: ['_NL', 'WS_INLINE', 'DEC_NUMBER'], accept_terminals: ['_NL', 'NOT'], accept_terminals: ['_NL', '__IGNORE_1', 'LAMBDA'], accept_terminals: ['_NL', '__IGNORE_1', 'PASS'], accept_terminals: ['_NL', 'COMMENT', 'IF'], accept_terminals: ['_NL', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', '_NL'], accept_terminals: ['_NL', 'COMMENT', 'RETURN'], accept_terminals: ['_NL', 'WS_INLINE', 'LONG_STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'EOF'], accept_terminals: ['_NL', '__IGNORE_1', 'WHILE'], accept_terminals: ['_NL', '__IGNORE_1', 'NOT'], accept_terminals: ['_NL', 'COMMENT', 'LONG_STRING'], accept_terminals: ['_NL', 'PASS'], accept_terminals: ['_NL', 'WS_INLINE', 'MINUS'], accept_terminals: ['_NL', '__IGNORE_1', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'TRY'], accept_terminals: ['_NL', 'IMPORT'], accept_terminals: ['_NL', 'WS_INLINE', '$END'], accept_terminals: ['_NL', 'WS_INLINE', 'BREAK'], accept_terminals: ['_NL', 'WS_INLINE', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'RETURN'], accept_terminals: ['WS_INLINE'], accept_terminals: ['_NL', 'DEL'], accept_terminals: ['_NL', '__IGNORE_1', 'LBRACE'], accept_terminals: ['_NL', 'WS_INLINE', 'TRY'], accept_terminals: ['_NL', 'COMMENT', 'FROM'], accept_terminals: ['_NL', 'WS_INLINE', 'TILDE'], accept_terminals: ['_NL', 'HEX_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'MINUS'], accept_terminals: ['_NL', 'COMMENT', 'WITH'], accept_terminals: ['SEMICOLON'], accept_terminals: ['_NL', 'COMMENT', 'LBRACE'], accept_terminals: ['_NL', 'NAME'], accept_terminals: ['_NL', 'COMMENT', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'CLASS'], accept_terminals: ['_NL', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'FOR'], accept_terminals: ['_NL', '__IGNORE_1', 'ASYNC'], accept_terminals: ['_NL', '__IGNORE_1', 'FLOAT_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'NONE'], accept_terminals: ['_NL', 'WS_INLINE', 'LBRACE'], accept_terminals: ['_NL', 'NONLOCAL'], accept_terminals: ['_NL', 'COMMENT', 'LSQB'], accept_terminals: ['_NL', '$END'], accept_terminals: ['_NL', '__IGNORE_1', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'TRUE'], accept_terminals: ['_NL', 'COMMENT', 'LAMBDA'], accept_terminals: ['_NL', 'WS_INLINE', 'STAR'], accept_terminals: ['_NL', 'WS_INLINE', 'PASS'], accept_terminals: ['_NL', '__IGNORE_1', 'NONE'], accept_terminals: ['_NL', '__IGNORE_1', 'IMPORT'], accept_terminals: ['_NL', 'COMMENT', 'DEF'], accept_terminals: ['_NL', 'COMMENT', 'ASYNC'], accept_terminals: ['_NL', 'COMMENT', 'FALSE'], accept_terminals: ['_NL', 'TRUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'PASS'], accept_terminals: ['COMMA'], accept_terminals: ['_NL', 'WS_INLINE', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'NONLOCAL'], accept_terminals: ['_NL', 'WS_INLINE', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'WITH'], accept_termina ...
# [2025-08-09 18:14:33,599-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:34,017-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:34,418-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:34,837-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:35,250-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:35,644-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('scipy', <VarUseType.DEFINE: 'DEFINE'>), ('stats', <VarUseType.USE: 'USE'>)]
# [2025-08-09 18:14:35,648-syncode.grammar_mask.grammar_constrainer] - No acceptable tokens for the current partial code!
# [2025-08-09 18:14:35,650-syncode.grammar_mask.grammar_constrainer] - remainder : b'\n\n# matplotlib fun\n', remainder_state: RemainderState.MAYBE_COMPLETE, accept_sequences: {accept_terminals: ['_NL', 'COMMENT', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', 'ASSERT'], accept_terminals: ['_NL', 'WS_INLINE', 'WHILE'], accept_terminals: ['_NL', 'COMMENT', 'DEL'], accept_terminals: ['_NL', 'WS_INLINE', 'YIELD'], accept_terminals: ['_NL', 'COMMENT', 'YIELD'], accept_terminals: ['_NL', '__IGNORE_1', 'BREAK'], accept_terminals: ['_NL', '__IGNORE_1', 'FROM'], accept_terminals: ['_NL', '__IGNORE_1', 'STAR'], accept_terminals: ['_NL', 'TILDE'], accept_terminals: ['_NL', '__IGNORE_1', 'IF'], accept_terminals: ['_NL', 'FROM'], accept_terminals: ['_NL', '_NL'], accept_terminals: ['_NL', 'WS_INLINE', 'LSQB'], accept_terminals: ['_NL', 'STRING'], accept_terminals: ['_NL', 'COMMENT', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'HEX_NUMBER'], accept_terminals: ['_NL', 'WS_INLINE', 'WITH'], accept_terminals: ['_NL', 'WS_INLINE', 'DEC_NUMBER'], accept_terminals: ['_NL', 'NOT'], accept_terminals: ['_NL', '__IGNORE_1', 'LAMBDA'], accept_terminals: ['_NL', '__IGNORE_1', 'PASS'], accept_terminals: ['_NL', 'COMMENT', 'IF'], accept_terminals: ['_NL', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AT'], accept_terminals: ['_NL', '__IGNORE_1', '_NL'], accept_terminals: ['_NL', 'COMMENT', 'RETURN'], accept_terminals: ['_NL', 'WS_INLINE', 'LONG_STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'EOF'], accept_terminals: ['_NL', '__IGNORE_1', 'WHILE'], accept_terminals: ['_NL', '__IGNORE_1', 'NOT'], accept_terminals: ['_NL', 'COMMENT', 'LONG_STRING'], accept_terminals: ['_NL', 'PASS'], accept_terminals: ['_NL', 'WS_INLINE', 'MINUS'], accept_terminals: ['_NL', '__IGNORE_1', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'TRY'], accept_terminals: ['_NL', 'IMPORT'], accept_terminals: ['_NL', 'WS_INLINE', '$END'], accept_terminals: ['_NL', 'WS_INLINE', 'BREAK'], accept_terminals: ['_NL', 'WS_INLINE', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'RETURN'], accept_terminals: ['WS_INLINE'], accept_terminals: ['_NL', 'DEL'], accept_terminals: ['_NL', '__IGNORE_1', 'LBRACE'], accept_terminals: ['_NL', 'WS_INLINE', 'TRY'], accept_terminals: ['_NL', 'COMMENT', 'FROM'], accept_terminals: ['_NL', 'WS_INLINE', 'TILDE'], accept_terminals: ['_NL', 'HEX_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'MINUS'], accept_terminals: ['_NL', 'COMMENT', 'WITH'], accept_terminals: ['SEMICOLON'], accept_terminals: ['_NL', 'COMMENT', 'LBRACE'], accept_terminals: ['_NL', 'NAME'], accept_terminals: ['_NL', 'COMMENT', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'CLASS'], accept_terminals: ['_NL', 'OCT_NUMBER'], accept_terminals: ['_NL', '__IGNORE_1', 'FOR'], accept_terminals: ['_NL', '__IGNORE_1', 'ASYNC'], accept_terminals: ['_NL', '__IGNORE_1', 'FLOAT_NUMBER'], accept_terminals: ['_NL', 'COMMENT', 'NONE'], accept_terminals: ['_NL', 'WS_INLINE', 'LBRACE'], accept_terminals: ['_NL', 'NONLOCAL'], accept_terminals: ['_NL', 'COMMENT', 'LSQB'], accept_terminals: ['_NL', '$END'], accept_terminals: ['_NL', '__IGNORE_1', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'CONTINUE'], accept_terminals: ['_NL', '__IGNORE_1', 'TRUE'], accept_terminals: ['_NL', 'COMMENT', 'LAMBDA'], accept_terminals: ['_NL', 'WS_INLINE', 'STAR'], accept_terminals: ['_NL', 'WS_INLINE', 'PASS'], accept_terminals: ['_NL', '__IGNORE_1', 'NONE'], accept_terminals: ['_NL', '__IGNORE_1', 'IMPORT'], accept_terminals: ['_NL', 'COMMENT', 'DEF'], accept_terminals: ['_NL', 'COMMENT', 'ASYNC'], accept_terminals: ['_NL', 'COMMENT', 'FALSE'], accept_terminals: ['_NL', 'TRUE'], accept_terminals: ['_NL', '__IGNORE_1', 'AWAIT'], accept_terminals: ['_NL', 'COMMENT', 'PASS'], accept_terminals: ['COMMA'], accept_terminals: ['_NL', 'WS_INLINE', 'GLOBAL'], accept_terminals: ['_NL', '__IGNORE_1', 'NONLOCAL'], accept_terminals: ['_NL', 'WS_INLINE', 'STRING'], accept_terminals: ['_NL', '__IGNORE_1', 'WITH ...
# [2025-08-09 18:14:36,042-syncode.parsers.python_var_tracking_parser] - vars: [('np', <VarUseType.DEFINE: 'DEFINE'>), ('norm', <VarUseType.DEFINE: 'DEFINE'>)]
# # numpy fun
# import numpy as np
#
# # scipy fun
# from scipy.stats import norm
#
# # matplotlib fun
# import mat
